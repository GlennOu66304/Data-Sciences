# %%
import requests
from bs4 import BeautifulSoup
start=0
result=[]
header={
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36'
}
for i in range(0,10):
    html = requests.get('https://movie.douban.com/top250?start=' + str(start) + '&filter=',headers=header)
    html.encoding='utf-8'
    start+=25
    soup=BeautifulSoup(html.text,'html.parser')
    
    for item in soup.find_all('div','info'):
        title=item.div.a.span.string
        yearline=item.find('div','bd').p.contents[2].string
        yearline=yearline.replace('\n','')
        yearline=yearline.replace(' ','')
        year=yearline[0:4]
        
        rating=item.find('span',{'class':'rating_num'}).get_text()
        oneresult=[title,rating,year]
        result.append(oneresult)
        
print(result)
# Out:
# [['肖申克的救赎', '9.7', '1994'], ['霸王别姬', '9.6', '1993'], ['阿甘正传', '9.5', '1994'], ['这个杀手不太冷', '9.4', '1994'], ['美丽人生', '9.5', '1997'], ['泰坦尼克号', '9.4', '1997'], ['千与千寻', '9.4', '2001'], ['辛德勒的名单', '9.5', '1993'], ['盗梦空间', '9.3', '2010'], ['忠犬八公的故事', '9.4', '2009'], ['海上钢琴师', '9.3', '1998'], ['楚门的世界', '9.3', '1998'], ['三傻大闹宝莱坞', '9.2', '2009'], ['机器人总动员', '9.3', '2008'], ['放牛班的春天', '9.3', '2004'], ['星际穿越', '9.3', '2014'], ['大话西游之大圣娶亲', '9.2', '1995'], ['熔炉', '9.3', '2011'], ['疯狂动物城', '9.2', '2016'], ['无间道', '9.2', '2002'], ['龙猫', '9.2', '1988'], ['教父', '9.3', '1972'], ['当幸福来敲门', '9.1', '2006'], ['怦然心动', '9.1', '2010'], ['触不可及', '9.2', '2011'], ['蝙蝠侠：黑暗骑士', '9.2', '2008'], ['控方证人', '9.6', '1957'], ['活着', '9.2', '1994'], ['乱世佳人', '9.3', '1939'], ['寻梦环游记', '9.1', '2017'], ['末代皇帝', '9.2', '1987'], ['摔跤吧！爸爸', '9.0', '2016'], ['指环王3：王者无敌', '9.2', '2003'], ['何以为家', '9.1', '2018'], ['少年派的奇幻漂流', '9.1', '2012'], ['飞屋环游记', '9.0', '2009'], ['十二怒汉', '9.4', '1957'], ['鬼子来了', '9.2', '2000'], ['天空之城', '9.1', '1986'], ['大话西游之月光宝盒', '9.0', '1995'], ['哈尔的移动城堡', '9.1', '2004'], ['素媛', '9.2', '2013'], ['天堂电影院', '9.2', '1988'], ['罗马假日', '9.0', '1953'], ['闻香识女人', '9.1', '1992'], ['辩护人', '9.2', '2013'], ['哈利·波特与魔法石', '9.0', '2001'], ['搏击俱乐部', '9.0', '1999'], ['我不是药神', '9.0', '2018'], ['死亡诗社', '9.1', '1989'], ['教父2', '9.2', '1974'], ['指环王2：双塔奇兵', '9.1', '2002'], ['狮子王', '9.0', '1994'], ['窃听风暴', '9.1', '2006'], ['大闹天宫', '9.3', '1961'], ['指环王1：魔戒再现', '9.0', '2001'], ['两杆大烟枪', '9.1', '1998'], ['美丽心灵', '9.0', '2001'], ['饮食男女', '9.1', '1994'], ['猫鼠游戏', '9.0', '2002'], ['飞越疯人院', '9.1', '1975'], ['黑客帝国', '9.0', '1999'], ['钢琴家', '9.2', '2002'], ['V字仇杀队', '8.9', '2005'], ['本杰明·巴顿奇事', '8.9', '2008'], ['看不见的客人', '8.8', '2016'], ['让子弹飞', '8.8', '2010'], ['西西里的美丽传说', '8.9', '2000'], ['小鞋子', '9.2', '1997'], ['海豚湾', '9.3', '2009'], ['拯救大兵瑞恩', '9.0', '1998'], ['情书', '8.9', '1995'], ['穿条纹睡衣的男孩', '9.1', '2008'], ['音乐之声', '9.0', '1965'], ['美国往事', '9.2', '1984'], ['绿皮书', '8.9', '2018'], ['致命魔术', '8.9', '2006'], ['海蒂和爷爷', '9.2', '2015'], ['低俗小说', '8.8', '1994'], ['七宗罪', '8.8', '1995'], ['沉默的羔羊', '8.8', '1991'], ['蝴蝶效应', '8.8', '2004'], ['春光乍泄', '8.9', '1997'], ['禁闭岛', '8.8', '2010'], ['被嫌弃的松子的一生', '8.9', '2006'], ['心灵捕手', '8.9', '1997'], ['布达佩斯大饭店', '8.8', '2014'], ['阿凡达', '8.7', '2009'], ['剪刀手爱德华', '8.7', '1990'], ['勇敢的心', '8.9', '1995'], ['摩登时代', '9.3', '1936'], ['天使爱美丽', '8.7', '2001'], ['喜剧之王', '8.7', '1999'], ['致命ID', '8.8', '2003'], ['加勒比海盗', '8.7', '2003'], ['断背山', '8.8', '2005'], ['杀人回忆', '8.8', '2003'], ['狩猎', '9.1', '2012'], ['幽灵公主', '8.9', '1997'], ['哈利·波特与死亡圣器(下)', '8.8', '2011'], ['请以你的名字呼唤我', '8.9', '2017'], ['阳光灿烂的日子', '8.8', '1994'], ['入殓师', '8.8', '2008'], ['重庆森林', '8.7', '1994'], ['第六感', '8.9', '1999'], ['小森林 夏秋篇', '9.0', '2014'], ['7号房的礼物', '8.9', '2013'], ['消失的爱人', '8.7', '2014'], ['红辣椒', '9.0', '2006'], ['小森林 冬春篇', '9.0', '2015'], ['爱在黎明破晓前', '8.8', '1995'], ['侧耳倾听', '8.9', '1995'], ['玛丽和马克思', '8.9', '2009'], ['一一', '9.0', '2000'], ['唐伯虎点秋香', '8.6', '1993'], ['告白', '8.7', '2010'], ['蝙蝠侠：黑暗骑士崛起', '8.8', '2012'], ['大鱼', '8.8', '2003'], ['阳光姐妹淘', '8.8', '2011'], ['倩女幽魂', '8.7', '1987'], ['超脱', '8.9', '2011'], ['射雕英雄传之东成西就', '8.7', '1993'], ['萤火之森', '8.9', '2011'], ['甜蜜蜜', '8.8', '1996'], ['驯龙高手', '8.7', '2010'], ['无人知晓', '9.1', '2004'], ['超能陆战队', '8.7', '2014'], ['幸福终点站', '8.8', '2004'], ['菊次郎的夏天', '8.8', '1999'], ['借东西的小人阿莉埃蒂', '8.8', '2010'], ['爱在日落黄昏时', '8.8', '2004'], ['恐怖直播', '8.8', '2013'], ['完美的世界', '9.1', '1993'], ['神偷奶爸', '8.6', '2010'], ['怪兽电力公司', '8.7', '2001'], ['玩具总动员3', '8.8', '2010'], ['风之谷', '8.9', '1984'], ['血战钢锯岭', '8.7', '2016'], ['功夫', '8.6', '2004'], ['傲慢与偏见', '8.6', '2005'], ['上帝之城', '8.9', '2002'], ['时空恋旅人', '8.7', '2013'], ['教父3', '8.9', '1990'], ['人生果实', '9.5', '2017'], ['电锯惊魂', '8.7', '2004'], ['喜宴', '8.9', '1993'], ['天书奇谭', '9.2', '1983'], ['谍影重重3', '8.8', '2007'], ['英雄本色', '8.7', '1986'], ['被解救的姜戈', '8.7', '2012'], ['岁月神偷', '8.7', '2010'], ['七武士', '9.2', '1954'], ['哪吒闹海', '9.1', '1979'], ['我是山姆', '8.9', '2001'], ['疯狂原始人', '8.7', '2 ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)

# %%
df
# Out:
#                 0    1     2
# 0          肖申克的救赎  9.7  1994
# 1            霸王别姬  9.6  1993
# 2            阿甘正传  9.5  1994
# 3         这个杀手不太冷  9.4  1994
# 4            美丽人生  9.5  1997
# 5           泰坦尼克号  9.4  1997
# 6            千与千寻  9.4  2001
# 7          辛德勒的名单  9.5  1993
# 8            盗梦空间  9.3  2010
# 9         忠犬八公的故事  9.4  2009
# 10          海上钢琴师  9.3  1998
# 11          楚门的世界  9.3  1998
# 12        三傻大闹宝莱坞  9.2  2009
# 13         机器人总动员  9.3  2008
# 14         放牛班的春天  9.3  2004
# 15           星际穿越  9.3  2014
# 16      大话西游之大圣娶亲  9.2  1995
# 17             熔炉  9.3  2011
# 18          疯狂动物城  9.2  2016
# 19            无间道  9.2  2002
# 20             龙猫  9.2  1988
# 21             教父  9.3  1972
# 22         当幸福来敲门  9.1  2006
# 23           怦然心动  9.1  2010
# 24           触不可及  9.2  2011
# 25       蝙蝠侠：黑暗骑士  9.2  2008
# 26           控方证人  9.6  1957
# 27             活着  9.2  1994
# 28           乱世佳人  9.3  1939
# 29          寻梦环游记  9.1  2017
# ..            ...  ...   ...
# 220        地球上的星星  8.9  2007
# 221          谍影重重  8.6  2002
# 222          战争之王  8.6  2005
# 223            血钻  8.7  2006
# 224           猜火车  8.5  1996
# 225           色，戒  8.4  2007
# 226          遗愿清单  8.6  2007
# 227         大佛普拉斯  8.7  2017
# 228  疯狂的麦克斯4：狂暴之路  8.6  2015
# 229          步履不停  8.8  2008
# 230       彗星来的那一夜  8.5  2013
# 231           朗读者  8.6  2008
# 232            浪潮  8.7  2008
# 233      小萝莉的猴神大叔  8.4  2015
# 234    再次出发之纽约遇见你  8.5  2013
# 235            聚焦  8.8  2015
# 236           驴得水  8.3  2016
# 237          东京物语  9.2  1953
# 238            追随  8.9  1998
# 239          一次别离  8.7  2011
# 240         九品芝麻官  8.5  1994
# 241          千钧一发  8.8  1997
# 242           我爱你  9.0  2011
# 243          黑鹰坠落  8.7  2001
# 244     哈利·波特与火焰杯  8.5  2005
# 245          四个春天  8.9  2017
# 246          网络谜踪  8.6  2018
# 247           发条橙  8.5  1971
# 248      E.T. 外星人  8.6  1982
# 249    黑客帝国2：重装上阵  8.6  2003
#
# [250 rows x 3 columns]

# %%
df.to_excel("Craw 豆瓣网评分最高的250部电影.xlsx")
